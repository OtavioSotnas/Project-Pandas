# %%
import pandas as pd
import numpy as np

# %%
url_sellers = 'https://raw.githubusercontent.com/OtavioSotnas/Trabalhinho-Ada-PT2/main/base%20de%20dados/olist_sellers_dataset.csv'

# %%
df_sellers = pd.read_csv(url_sellers)

# %%
df_vendedores = df_sellers.rename(columns={
    'seller_id': 'id_vendedor',
    'seller_zip_code_prefix' : 'cep_vendedor',
    'seller_city' : 'cidade_vendedor',
    'seller_state' : 'estado_vendedor'})

# %%
df_vendedores['cidade_vendedor'] = df_vendedores['cidade_vendedor'].str.title()

# %%
df_vendedores['cidade_estado'] = df_vendedores['cidade_vendedor'] + ' - ' + df_vendedores['estado_vendedor']

# %%
df_vendedores.head(10)
# Out:
#                         id_vendedor  cep_vendedor    cidade_vendedor  \
# 0  3442f8959a84dea7ee197c632cb2df15         13023           Campinas
# 1  d1b65fc7debc3361ea86b5f14c68d2e2         13844         Mogi Guacu
# 2  ce3ad9de960102d0677a81f5d0bb7b2d         20031     Rio De Janeiro
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3          4195          Sao Paulo
# 4  51a04a8a6bdcb23deccc82b0b80742cf         12914  Braganca Paulista
# 5  c240c4061717ac1806ae6ee72be3533b         20920     Rio De Janeiro
# 6  e49c26c3edfa46d227d5121a6b6e4d37         55325             Brejao
# 7  1b938a7ec6ac5061a66a3766e0e75f90         16304          Penapolis
# 8  768a86e36ad6aae3d03ee3c6433d61df          1529          Sao Paulo
# 9  ccc4bbb5f32a6ab2b7066a4130f114e3         80310           Curitiba
#
#   estado_vendedor           cidade_estado
# 0              SP           Campinas - SP
# 1              SP         Mogi Guacu - SP
# 2              RJ     Rio De Janeiro - RJ
# ...

# %%
df_vendedores.isnull().sum() # Esses dados não contem valores nulos
# Out:
# id_vendedor        0
# cep_vendedor       0
# cidade_vendedor    0
# estado_vendedor    0
# cidade_estado      0
# dtype: int64

# %%
df_vendedores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id_vendedor      3095 non-null   object
#  1   cep_vendedor     3095 non-null   int64
#  2   cidade_vendedor  3095 non-null   object
#  3   estado_vendedor  3095 non-null   object
#  4   cidade_estado    3095 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 121.0+ KB

# %%
df_vendedores.value_counts('estado_vendedor', ascending=True, normalize=True).tail(10).\
plot(
    kind='barh', figsize=(10,4), xlabel='Porcentagem', ylabel='Estados', 
    title='10 maiores estados onde moram os vendedores'
    )
# Out:
# <Axes: title={'center': '10 maiores estados onde moram os vendedores'}, xlabel='Porcentagem', ylabel='Estados'>

# %%
df_vendedores.value_counts('cidade_vendedor', ascending=True, normalize=True).tail(15).\
plot(
    kind='barh', figsize=(10,4), xlabel='Porcentagem', ylabel='Cidades', 
    title='15 maiores cidades onde moram os vendedores', color='green'
    )
# Out:
# <Axes: title={'center': '15 maiores cidades onde moram os vendedores'}, xlabel='Porcentagem', ylabel='Cidades'>
